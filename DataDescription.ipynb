# %% [raw]
# ---
# title: Data Set Descriptive Statistics
# ---

# %% [markdown]
# This notebook just has basic descriptive stats of the data set.
#
#
# ## Setup
#
# Import modules:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from lenskit.datasets import ML1M
from lkdemo.plotutils import *

# %%
ml = ML1M('data/ml-1m/')

# %%
fig_dir = init_figs('DataDescription')
print(fig_dir)
# Out:
# using figure dir figures/DataDescription
# figures/DataDescription

# %% [markdown]
# ## Basic Shape and Size

# %%
ratings = ml.ratings
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user       1000209 non-null  int32
#  1   item       1000209 non-null  int32
#  2   rating     1000209 non-null  float32
#  3   timestamp  1000209 non-null  int32
# dtypes: float32(1), int32(3)
# memory usage: 15.3 MB

# %% [markdown]
# How much data?

# %%
pd.Series({
    'ratings': len(ratings),
    'users': ratings['user'].nunique(),
    'items': ratings['item'].nunique(),
})
# Out:
# ratings    1000209
# users         6040
# items         3706
# dtype: int64

# %% [markdown]
# ## User Demographics

# %%
users = ml.users
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6040 entries, 1 to 6040
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  6040 non-null   category
#  1   age     6040 non-null   int8
#  2   zip     6040 non-null   object
# dtypes: category(1), int8(1), object(1)
# memory usage: 106.2+ KB

# %% [markdown]
# Distribution of genders:

# %%
sns.countplot(users, x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# Distribution of ages:

# %%
sns.countplot(users, x='age')
# Out:
# <Axes: xlabel='age', ylabel='count'>
